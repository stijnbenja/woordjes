# %%
import requests

# %%
application_id = "581889"
access_key = "m9CxMc54nNM3WKgINkoQRuVkKIOwwgvSWmLhJDi1dp0"
secret_key = 'GLYOlfSj3nx7Ftd5RXIWfRH4RrTX1X0AMg-lBDVslCY'

# %%
url = "https://api.unsplash.com//search/photos"

# %%
parameters = {'client_id':access_key, 'query':'walking'}

res = requests.get(url, params=parameters)
res.text
# Out:
# '{"total":10000,"total_pages":1000,"results":[{"id":"M4axlwlzKCE","slug":"calico-cat-on-brown-wooden-table-M4axlwlzKCE","alternative_slugs":{"en":"calico-cat-on-brown-wooden-table-M4axlwlzKCE","es":"gato-calico-sobre-mesa-de-madera-marron-M4axlwlzKCE","ja":"茶色の木製のテーブルに三毛猫-M4axlwlzKCE","fr":"chat-calicot-sur-table-en-bois-marron-M4axlwlzKCE","it":"gatto-calico-su-tavolo-di-legno-marrone-M4axlwlzKCE","ko":"갈색-나무-테이블에-옥양목-고양이-M4axlwlzKCE","de":"kaliko-katze-auf-braunem-holztisch-M4axlwlzKCE","pt":"gato-calico-na-mesa-de-madeira-marrom-M4axlwlzKCE"},"created_at":"2020-03-14T16:39:06Z","updated_at":"2024-03-18T18:11:41Z","promoted_at":null,"width":4000,"height":6000,"color":"#0c2626","blur_hash":"LSBg[F%%x^tS%is;RPV@o~aIRjWA","description":"We fount this little munchkin eating her food on the streets of Jakarta. ","alt_description":"calico cat on brown wooden table","breadcrumbs":[],"urls":{"raw":"https://images.unsplash.com/photo-1584203910443-56d93e9ec88b?ixid=M3w1ODE4ODl8MHwxfHNlYXJjaH
# ...

# %%
res.json()['results'][0]['urls']['small']
# Out:
# 'https://images.unsplash.com/photo-1584203910443-56d93e9ec88b?crop=entropy&cs=tinysrgb&fit=max&fm=jpg&ixid=M3w1ODE4ODl8MHwxfHNlYXJjaHwxfHxlYXRpbmclMjBwdXNzeXxlbnwwfHx8fDE3MTEwNDU2NDZ8MA&ixlib=rb-4.0.3&q=80&w=400'
